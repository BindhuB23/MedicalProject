# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
df=pd.read_csv("medical_cost (1).csv")
df
# Out:
#         Id  age     sex     bmi  children smoker     region      charges
# 0        1   19  female  27.900         0    yes  southwest  16884.92400
# 1        2   18    male  33.770         1     no  southeast   1725.55230
# 2        3   28    male  33.000         3     no  southeast   4449.46200
# 3        4   33    male  22.705         0     no  northwest  21984.47061
# 4        5   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  1334   50    male  30.970         3     no  northwest  10600.54830
# 1334  1335   18  female  31.920         0     no  northeast   2205.98080
# 1335  1336   18  female  36.850         0     no  southeast   1629.83350
# 1336  1337   21  female  25.800         0     no  southwest   2007.94500
# 1337  1338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
df.replace("?",np.nan,inplace=True)
df.isnull().sum()
# Out:
# Id          0
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sn.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %%
df.describe()
# Out:
#                 Id          age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean    669.500000    39.207025    30.663397     1.094918  13270.422265
# std     386.391641    14.049960     6.098187     1.205493  12110.011237
# min       1.000000    18.000000    15.960000     0.000000   1121.873900
# 25%     335.250000    27.000000    26.296250     0.000000   4740.287150
# 50%     669.500000    39.000000    30.400000     1.000000   9382.033000
# 75%    1003.750000    51.000000    34.693750     2.000000  16639.912515
# max    1338.000000    64.000000    53.130000     5.000000  63770.428010

# %%
df['smoker']=df['smoker'].astype('category')
df['smoker']=df['smoker'].cat.codes
df
# Out:
#         Id  age     sex     bmi  children  smoker     region      charges
# 0        1   19  female  27.900         0       1  southwest  16884.92400
# 1        2   18    male  33.770         1       0  southeast   1725.55230
# 2        3   28    male  33.000         3       0  southeast   4449.46200
# 3        4   33    male  22.705         0       0  northwest  21984.47061
# 4        5   32    male  28.880         0       0  northwest   3866.85520
# ...    ...  ...     ...     ...       ...     ...        ...          ...
# 1333  1334   50    male  30.970         3       0  northwest  10600.54830
# 1334  1335   18  female  31.920         0       0  northeast   2205.98080
# 1335  1336   18  female  36.850         0       0  southeast   1629.83350
# 1336  1337   21  female  25.800         0       0  southwest   2007.94500
# 1337  1338   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
df['region']=df['region'].astype('category')
df['region']=df['region'].cat.codes
df
# Out:
#         Id  age     sex     bmi  children  smoker  region      charges
# 0        1   19  female  27.900         0       1       3  16884.92400
# 1        2   18    male  33.770         1       0       2   1725.55230
# 2        3   28    male  33.000         3       0       2   4449.46200
# 3        4   33    male  22.705         0       0       1  21984.47061
# 4        5   32    male  28.880         0       0       1   3866.85520
# ...    ...  ...     ...     ...       ...     ...     ...          ...
# 1333  1334   50    male  30.970         3       0       1  10600.54830
# 1334  1335   18  female  31.920         0       0       0   2205.98080
# 1335  1336   18  female  36.850         0       0       2   1629.83350
# 1336  1337   21  female  25.800         0       0       3   2007.94500
# 1337  1338   61  female  29.070         0       1       1  29141.36030
#
# [1338 rows x 8 columns]

# %%
df['sex']=df['sex'].astype('category')
df['sex']=df['sex'].cat.codes
df.head()
# Out:
#    Id  age  sex     bmi  children  smoker  region      charges
# 0   1   19    0  27.900         0       1       3  16884.92400
# 1   2   18    1  33.770         1       0       2   1725.55230
# 2   3   28    1  33.000         3       0       2   4449.46200
# 3   4   33    1  22.705         0       0       1  21984.47061
# 4   5   32    1  28.880         0       0       1   3866.85520

# %%
x=df.iloc[:,1:7]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 355    46    1  27.600         0       0       3
# 477    25    1  35.625         0       0       1
# 1156   19    1  44.880         0       1       2
# 663    18    1  33.660         0       0       2
# 1216   40    1  25.080         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 466    60    0  28.700         1       0       3
# 299    48    0  28.880         1       0       1
# 493    61    1  43.400         0       0       3
# 527    51    0  25.800         1       0       3
# 1192   58    0  32.395         1       0       0
#
# [936 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %% [markdown]
# # 70:30

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from mpl_toolkits.mplot3d import Axes3D

# Define parameter grids
param_grid_rf = {
    'n_estimators': [100, 150, 200],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}
param_grid_lr = {
    'fit_intercept': [True, False],
    
}
param_grid_svr = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto'],
    'degree': [3, 4, 5]
}

# Initialize models
models = {
    'Random Forest': (RandomForestRegressor(), param_grid_rf),
    'Linear Regression': (LinearRegression(), param_grid_lr),
    'Support Vector Regressor': (SVR(), param_grid_svr)
}

results = {
    'Model': [],
    'Dataset': [],
    'MAE': [],
    'MSE': [],
    'RMSE': [],
    'R2': []
}

# Perform grid search and evaluate each model
for model_name, (model, param_grid) in models.items():
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2').fit(x_train_scaled, y_train)
    best_model = model.set_params(**grid_search.best_params_)
    best_model.fit(x_train_scaled, y_train)
    
    # Training set
    y_pred_train = best_model.predict(x_train_scaled)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mse_train = mean_squared_error(y_train, y_pred_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_train, y_pred_train)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Training')
    results['MAE'].append(mae_train)
    results['MSE'].append(mse_train)
    results['RMSE'].append(rmse_train)
    results['R2'].append(r2_train)
    
    # Testing set
    y_pred_test = best_model.predict(x_test_scaled)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    mse_test = mean_squared_error(y_test, y_pred_test)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test, y_pred_test)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Testing')
    results['MAE'].append(mae_test)
    results['MSE'].append(mse_test)
    results['RMSE'].append(rmse_test)
    results['R2'].append(r2_test)

# Print the results
for i in range(0, len(results['Model']), 2):
    print(f"Model: {results['Model'][i]}")
    print(f"  Training Set:")
    print(f"    MAE: {results['MAE'][i]}")
    print(f"    MSE: {results['MSE'][i]}")
    print(f"    RMSE: {results['RMSE'][i]}")
    print(f"    R2: {results['R2'][i]}")
    print(f"  Testing Set:")
    print(f"    MAE: {results['MAE'][i+1]}")
    print(f"    MSE: {results['MSE'][i+1]}")
    print(f"    RMSE: {results['RMSE'][i+1]}")
    print(f"    R2: {results['R2'][i+1]}")
# Out:
# Model: Random Forest
#   Training Set:
#     MAE: 1902.750137410249
#     MSE: 11846767.041690648
#     RMSE: 3441.9132821282187
#     R2: 0.9154158555612566
#   Testing Set:
#     MAE: 2516.0230364901995
#     MSE: 20840607.66092718
#     RMSE: 4565.151438991611
#     R2: 0.8710665882619013
# Model: Linear Regression
#   Training Set:
#     MAE: 4189.452987485207
#     MSE: 36028634.91338632
#     RMSE: 6002.3857684579325
#     R2: 0.7427609364883972
#   Testing Set:
#     MAE: 4288.95751355982
#     MSE: 38010670.32913278
#     RMSE: 6165.279420199281
#     R2: 0.7648415301644245
# Model: Support Vector Regressor
#   Training Set:
#     MAE: 2508.5091715075323
#     MSE: 25416088.336053453
#     RMSE: 5041.437130030826
#     R2: 0.8185329314471089
#   Testing Set:
#     MAE: 2963.480023918413
#     MSE: 32279155.302562002
#     RMSE: 5681.474747155179
#     R2: 0.8003003708482989

# %%
fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(results['Model'][::2]))  # the label locations
width = 0.35  # the width of the bars

# Extract R2 scores for train and test sets
y_train_r2 = np.array([results['R2'][j] for j in range(0, len(results['Model']), 2)])
y_test_r2 = np.array([results['R2'][j] for j in range(1, len(results['Model']), 2)])

# Plot bars
ax.bar(x - width/2, y_train_r2, width, label='Train R2', color='blue')
ax.bar(x + width/2, y_test_r2, width, label='Test R2', color='orange')

# Annotate bars with model names
ax.set_xticks(x)
ax.set_xticklabels(results['Model'][::2], rotation=45, ha='right')

ax.set_xlabel('Model')
ax.set_ylabel('R2 Score')
ax.set_title('R2 Score Comparison of Different Models(70:30)')
ax.legend()
plt.show()

# %% [markdown]
# # 80:20

# %%
x=df.iloc[:,1:7]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 882    21    0  22.135         0       0       0
# 505    37    1  30.875         3       0       1
# 798    58    0  33.100         0       0       3
# 792    22    0  23.180         0       0       0
# 201    48    0  32.230         1       0       2
# ...   ...  ...     ...       ...     ...     ...
# 466    60    0  28.700         1       0       3
# 299    48    0  28.880         1       0       1
# 493    61    1  43.400         0       0       3
# 527    51    0  25.800         1       0       3
# 1192   58    0  32.395         1       0       0
#
# [1070 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from mpl_toolkits.mplot3d import Axes3D

# Define parameter grids
param_grid_rf = {
    'n_estimators': [100, 150, 200],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}
param_grid_lr = {
    'fit_intercept': [True, False],
    
}
param_grid_svr = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto'],
    'degree': [3, 4, 5]
}

# Initialize models
models = {
    'Random Forest': (RandomForestRegressor(), param_grid_rf),
    'Linear Regression': (LinearRegression(), param_grid_lr),
    'Support Vector Regressor': (SVR(), param_grid_svr)
}

results = {
    'Model': [],
    'Dataset': [],
    'MAE': [],
    'MSE': [],
    'RMSE': [],
    'R2': []
}

# Perform grid search and evaluate each model
for model_name, (model, param_grid) in models.items():
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2').fit(x_train_scaled, y_train)
    best_model = model.set_params(**grid_search.best_params_)
    best_model.fit(x_train_scaled, y_train)
    
    # Training set
    y_pred_train = best_model.predict(x_train_scaled)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mse_train = mean_squared_error(y_train, y_pred_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_train, y_pred_train)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Training')
    results['MAE'].append(mae_train)
    results['MSE'].append(mse_train)
    results['RMSE'].append(rmse_train)
    results['R2'].append(r2_train)
    
    # Testing set
    y_pred_test = best_model.predict(x_test_scaled)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    mse_test = mean_squared_error(y_test, y_pred_test)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test, y_pred_test)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Testing')
    results['MAE'].append(mae_test)
    results['MSE'].append(mse_test)
    results['RMSE'].append(rmse_test)
    results['R2'].append(r2_test)

# Print the results
for i in range(0, len(results['Model']), 2):
    print(f"Model: {results['Model'][i]}")
    print(f"  Training Set:")
    print(f"    MAE: {results['MAE'][i]}")
    print(f"    MSE: {results['MSE'][i]}")
    print(f"    RMSE: {results['RMSE'][i]}")
    print(f"    R2: {results['R2'][i]}")
    print(f"  Testing Set:")
    print(f"    MAE: {results['MAE'][i+1]}")
    print(f"    MSE: {results['MSE'][i+1]}")
    print(f"    RMSE: {results['RMSE'][i+1]}")
    print(f"    R2: {results['R2'][i+1]}")
# Out:
# Model: Random Forest
#   Training Set:
#     MAE: 1926.3518272956744
#     MSE: 12723706.73822119
#     RMSE: 3567.0305210666743
#     R2: 0.9125978934386515
#   Testing Set:
#     MAE: 2449.6048615384175
#     MSE: 20579663.96299377
#     RMSE: 4536.481451851619
#     R2: 0.8629673753203
# Model: Linear Regression
#   Training Set:
#     MAE: 4140.028379854144
#     MSE: 36104122.875132434
#     RMSE: 6008.670641259382
#     R2: 0.7519923667088932
#   Testing Set:
#     MAE: 4285.219437633698
#     MSE: 38364832.190545514
#     RMSE: 6193.935113523996
#     R2: 0.7445422986536503
# Model: Support Vector Regressor
#   Training Set:
#     MAE: 2530.0315896872876
#     MSE: 25707989.692134093
#     RMSE: 5070.304694210605
#     R2: 0.8234058281302323
#   Testing Set:
#     MAE: 2728.558642787351
#     MSE: 28523681.465627257
#     RMSE: 5340.756637933174
#     R2: 0.8100710029186495

# %%
fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(results['Model'][::2]))  # the label locations
width = 0.35  # the width of the bars

# Extract R2 scores for train and test sets
y_train_r2 = np.array([results['R2'][j] for j in range(0, len(results['Model']), 2)])
y_test_r2 = np.array([results['R2'][j] for j in range(1, len(results['Model']), 2)])

# Plot bars
ax.bar(x - width/2, y_train_r2, width, label='Train R2', color='cyan')
ax.bar(x + width/2, y_test_r2, width, label='Test R2', color='magenta')

# Annotate bars with model names
ax.set_xticks(x)
ax.set_xticklabels(results['Model'][::2], rotation=45, ha='right')

ax.set_xlabel('Model')
ax.set_ylabel('R2 Score')
ax.set_title('R2 Score Comparison of Different Models(80:20)')
ax.legend()
plt.show()

# %% [markdown]
# # 75:25

# %%
x=df.iloc[:,1:7]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2)
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 612    18    0  33.155         0       0       0
# 1093   22    0  30.400         0       1       1
# 757    47    0  27.830         0       1       2
# 556    46    1  33.440         1       0       0
# 829    39    1  21.850         1       0       1
# ...   ...  ...     ...       ...     ...     ...
# 466    60    0  28.700         1       0       3
# 299    48    0  28.880         1       0       1
# 493    61    1  43.400         0       0       3
# 527    51    0  25.800         1       0       3
# 1192   58    0  32.395         1       0       0
#
# [1003 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from mpl_toolkits.mplot3d import Axes3D

# Define parameter grids
param_grid_rf = {
    'n_estimators': [100, 150, 200],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}
param_grid_lr = {
    'fit_intercept': [True, False],
    
}
param_grid_svr = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto'],
    'degree': [3, 4, 5]
}

# Initialize models
models = {
    'Random Forest': (RandomForestRegressor(), param_grid_rf),
    'Linear Regression': (LinearRegression(), param_grid_lr),
    'Support Vector Regressor': (SVR(), param_grid_svr)
}

results = {
    'Model': [],
    'Dataset': [],
    'MAE': [],
    'MSE': [],
    'RMSE': [],
    'R2': []
}

# Perform grid search and evaluate each model
for model_name, (model, param_grid) in models.items():
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2').fit(x_train_scaled, y_train)
    best_model = model.set_params(**grid_search.best_params_)
    best_model.fit(x_train_scaled, y_train)
    
    # Training set
    y_pred_train = best_model.predict(x_train_scaled)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mse_train = mean_squared_error(y_train, y_pred_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_train, y_pred_train)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Training')
    results['MAE'].append(mae_train)
    results['MSE'].append(mse_train)
    results['RMSE'].append(rmse_train)
    results['R2'].append(r2_train)
    
    # Testing set
    y_pred_test = best_model.predict(x_test_scaled)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    mse_test = mean_squared_error(y_test, y_pred_test)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test, y_pred_test)
    
    results['Model'].append(model_name)
    results['Dataset'].append('Testing')
    results['MAE'].append(mae_test)
    results['MSE'].append(mse_test)
    results['RMSE'].append(rmse_test)
    results['R2'].append(r2_test)

# Print the results
for i in range(0, len(results['Model']), 2):
    print(f"Model: {results['Model'][i]}")
    print(f"  Training Set:")
    print(f"    MAE: {results['MAE'][i]}")
    print(f"    MSE: {results['MSE'][i]}")
    print(f"    RMSE: {results['RMSE'][i]}")
    print(f"    R2: {results['R2'][i]}")
    print(f"  Testing Set:")
    print(f"    MAE: {results['MAE'][i+1]}")
    print(f"    MSE: {results['MSE'][i+1]}")
    print(f"    RMSE: {results['RMSE'][i+1]}")
    print(f"    R2: {results['R2'][i+1]}")
# Out:
# Model: Random Forest
#   Training Set:
#     MAE: 1913.7591925978795
#     MSE: 12026863.444443418
#     RMSE: 3467.9768517744487
#     R2: 0.9170264128604607
#   Testing Set:
#     MAE: 2427.6006465688993
#     MSE: 20371639.901999045
#     RMSE: 4513.495308737902
#     R2: 0.8650215857099893
# Model: Linear Regression
#   Training Set:
#     MAE: 4187.33829253193
#     MSE: 36172357.01534591
#     RMSE: 6014.345934126662
#     R2: 0.7504461382870367
#   Testing Set:
#     MAE: 4201.136218008056
#     MSE: 37775340.66376901
#     RMSE: 6146.164711734385
#     R2: 0.7497081429580859
# Model: Support Vector Regressor
#   Training Set:
#     MAE: 2554.1481723578254
#     MSE: 25660711.726691693
#     RMSE: 5065.640307670067
#     R2: 0.8229662030875595
#   Testing Set:
#     MAE: 2722.3067260987123
#     MSE: 29644516.513002753
#     RMSE: 5444.677815353518
#     R2: 0.8035813586648712

# %%
fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(results['Model'][::2]))  # the label locations
width = 0.35  # the width of the bars

# Extract R2 scores for train and test sets
y_train_r2 = np.array([results['R2'][j] for j in range(0, len(results['Model']), 2)])
y_test_r2 = np.array([results['R2'][j] for j in range(1, len(results['Model']), 2)])

# Plot bars
ax.bar(x - width/2, y_train_r2, width, label='Train R2', color='green')
ax.bar(x + width/2, y_test_r2, width, label='Test R2', color='purple')

# Annotate bars with model names
ax.set_xticks(x)
ax.set_xticklabels(results['Model'][::2], rotation=45, ha='right')

ax.set_xlabel('Model')
ax.set_ylabel('R2 Score')
ax.set_title('R2 Score Comparison of Different Models(75:25)')
ax.legend()
plt.show()

# %%
import joblib

joblib.dump(best_model, 'medical_cost_prediction_model.pkl')
print("Model saved successfully!")
# Out:
# Model saved successfully!
